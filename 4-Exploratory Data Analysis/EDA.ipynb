# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# First of all we need to import our Data

# %%
# getting the current working directory
import os

print(os.getcwd())
# Out:
# C:\Users\taha_\OneDrive - ine.inpt.ma\Coding\Data Science\Data-Science-Cell-Training\EDA

# %%
# getting the files in the current directory

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'datadyalna.csv', 'EDA.ipynb']

# %%
# importing libs
import pandas as pd

# %%
dataset = pd.read_csv("datadyalna.csv")

# %%
# head() function takes the number of lines you wanna show as an argument
dataset.head(8)
# Out:
#     Timestamp                          Email            Full name Year &nbsp  \
# 0  6:46:28 AM         Simo.firnand@gmail.com     Hajjari mohammed       INE1
# 1  6:47:20 AM           yfourari01@gmail.com      Fourari Youssef       INE1
# 2  6:47:35 AM       Houlmounir2019@gmail.com          Houl mounir       INE1
# 3  6:47:59 AM         ahmednani015@gmail.com           Ahmed Nani       INE1
# 4  6:48:42 AM  barri.fatima.zahrae@gmail.com  Barri Fatima Zahrae       INE1
# 5  6:53:10 AM      achraf.sbai2012@gmail.com          Sbai Achraf       INE1
# 6  6:55:39 AM        ayouboulkadi5@gmail.com        Ayoub Oulkadi       INE1
# 7  6:58:50 AM         youness.ggfb@gmail.com       Soussi Youness       INE2
#
#   major &nbsp Python &nbsp laptop &nbsp Discord &nbsp         ID &nbsp
# 0        DATA          Yes          Yes            No  Heisenberg#9829
# 1      SESNUM          Yes          Yes           Yes              NaN
# ...

# %%
# info() 
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Timestamp      32 non-null     object
#  1   Email          32 non-null     object
#  2   Full name      32 non-null     object
#  3   Year &nbsp     32 non-null     object
#  4   major &nbsp    32 non-null     object
#  5   Python &nbsp   32 non-null     object
#  6   laptop &nbsp   30 non-null     object
#  7   Discord &nbsp  32 non-null     object
#  8   ID &nbsp       5 non-null      object
# dtypes: object(9)
# memory usage: 2.4+ KB

# %%
# shape
dataset.shape
# Out:
# (32, 9)

# %%
# describe() function gives a disc of all the columns
dataset.describe()
# Out:
#           Timestamp                 Email        Full name Year &nbsp  \
# count            32                    32               32         32
# unique           32                    32               32          2
# top     11:01:25 AM  mido921med@gmail.com  Bouarfa Oussama       INE1
# freq              1                     1                1         16
#
#        major &nbsp Python &nbsp laptop &nbsp Discord &nbsp ID &nbsp
# count           32           32           30            32        5
# unique           6            1            1             2        5
# top           DATA          Yes          Yes           Yes     None
# freq            12           32           30            28        1

# %%
# isnull() checking the null values
dataset.isnull()
# Out:
#     Timestamp  Email  Full name  Year &nbsp  major &nbsp  Python &nbsp  \
# 0       False  False      False       False        False         False
# 1       False  False      False       False        False         False
# 2       False  False      False       False        False         False
# 3       False  False      False       False        False         False
# 4       False  False      False       False        False         False
# 5       False  False      False       False        False         False
# 6       False  False      False       False        False         False
# 7       False  False      False       False        False         False
# 8       False  False      False       False        False         False
# 9       False  False      False       False        False         False
# 10      False  False      False       False        False         False
# 11      False  False      False       False        False         False
# ...

# %%
# isnull() + sum() combo 
dataset.isnull().sum()
# Out:
# Timestamp         0
# Email             0
# Full name         0
# Year &nbsp        0
# major &nbsp       0
# Python &nbsp      0
# laptop &nbsp      2
# Discord &nbsp     0
# ID &nbsp         27
# dtype: int64

# %% [markdown]
# ### Example of conditions
# new_dataframe = dataframe [ condition ] <br>
# new_dataframe = dataframe [ dataframe['year'] > 2000 ]

# %%
ine2_df = dataset [ dataset['Year &nbsp'] == 'INE2' ]

# %%
ine2_df
# Out:
#       Timestamp                           Email                 Full name  \
# 7    6:58:50 AM          youness.ggfb@gmail.com            Soussi Youness
# 8    7:24:54 AM         1naser.rachid@gmail.com              Rachid naser
# 10   7:35:20 AM    oussamabouarfa2001@gmail.com           Bouarfa Oussama
# 11   7:45:01 AM           Chadliwiam0@gmail.com               Wiam chadli
# 12   7:45:03 AM      hatimmouline2014@gmail.com             Hatim Mouline
# 13   7:49:03 AM        tahabouasria15@gmail.com             taha Bouasria
# 15   8:24:37 AM      imanemagzoul2000@gmail.com              AGZOUL Imane
# 17  11:01:25 AM      mohamedhachami68@gmail.com           Hachami Mohamed
# 19  10:46:35 AM  mohammedzerhouni2001@gmail.com           Mohammed Jawhar
# 20  12:45:30 PM         hajarslim2000@gmail.com             hajar slimani
# 22   7:08:42 AM       youssef.jehbali@gmail.com           YOUSSEF JEHBALI
# 24   7:55:37 AM            mido921med@gmail.com  BATRONE MOHAMED EL MEHDI
# ...

# %%
# INE2 Data members
ine2_data_df = dataset [ (dataset['Year &nbsp'] == 'INE2') & (dataset['major &nbsp'] == 'DATA') ]

# %%
# number of them
ine2_data_df['Timestamp'].count()
# Out:
# 4

# %%
ine2_data_name = ine2_data_df['Full name']

# %%
ine2_data_name.tolist()
# Out:
# ['AGZOUL Imane', 'Mohammed Jawhar', 'YOUSSEF JEHBALI', 'Chakouki El Hassan']

# %% [markdown]
# I see that there only 4 people in data since cell form the data ine2 which means they already know this field

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------<br>
# Okay so it's your turn now ask questions and some question about the data that we have here and try to answer them using EDA<br>----------------------------------------------------------------------------------------------------------------------------

# %%
# let's go
